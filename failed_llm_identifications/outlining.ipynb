# %%
# %pip install -r "requirements_outlines.txt"

# %%
import transformers
import accelerate
import outlines
import json
import pandas as pd
import torch
import tqdm
import gc
import ast
from outlines import from_transformers, Generator, models
from pydantic import BaseModel, Field
from typing import List, Optional

# %%
'''
This is a chunk for clearing model cache if it becomes necessary to switch to another model without having to reset
'''

# Delete the model object
del model
gc.collect()

# Clear PyTorch cache on GPU
torch.cuda.empty_cache()
torch.cuda.reset_peak_memory_stats()

# This is a comment to test git

# %%
def print_gpu_memory():
    if torch.cuda.is_available():
        print("Cuda available")
        print(f"GPU memory allocated: {torch.cuda.memory_allocated() / 1024**3:.2f} GB")
        print(f"GPU memory reserved: {torch.cuda.memory_reserved() / 1024**3:.2f} GB")

# Call this before and after model loading
print_gpu_memory()
# Out:
# Cuda available
# GPU memory allocated: 0.00 GB
# GPU memory reserved: 0.00 GB

# %%
model = from_transformers(
    transformers.AutoModelForCausalLM.from_pretrained("meta-llama/Llama-3.2-1B", device_map="auto", dtype=torch.bfloat16),
    transformers.AutoTokenizer.from_pretrained("meta-llama/Llama-3.2-1B")
)
#"meta-llama/Llama-3.2-1B"

# %%
'''
This is the DeepSeek 14b model, which at first glance seems to perform better than the Llama model. 
Definitely worth considering if this should be used instead.
'''

model = from_transformers(
    transformers.AutoModelForCausalLM.from_pretrained("deepseek-ai/DeepSeek-R1-Distill-Qwen-14B", device_map="auto", torch_dtype=torch.bfloat16),
    transformers.AutoTokenizer.from_pretrained("deepseek-ai/DeepSeek-R1-Distill-Qwen-14B")
)
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Fetching 4 files: 100%|██████████| 4/4 [00:34<00:00,  8.60s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:04<00:00,  1.17s/it]

# %%
# Defining the pydantic class which ensures the structured output from the llm
class BlameAnalysis(BaseModel):
    text: str = Field(description="The exact original sentence being analyzed")
    blame: bool = Field(description="Whether blame is present in the sentence")
    blamee: Optional[str] = Field(
        default=None,
        description="Who or what is being blamed (must not be empty if blame=true)"
    )
    arguments: Optional[str] = Field(
        default=None,
        description="What the blamee is being blamed for - the specific negative outcome (must not be empty if blame=true)"
    )

# %%
# Defining the pydantic class which ensures the structured output from the llm
class BlameAnalysis(BaseModel):
    text: str = Field(description="The exact original sentence being analyzed, never generate new tokens here")
    blame: bool = Field(description="Whether blame is present in the sentence, you must be very certain in your response here")

# %%
text_data = pd.read_csv("/work/RuneEgeskovTrust#9638/Bachelor/Bachelor_project/annotation_data_translated_version_03_10.csv", encoding='utf-8')

# %%
hello = ast.literal_eval(text_data.loc[2]["da_segmented_text"])
hello[651]
# Out:
# ''

# %%
paragraph_entry = {}
for i, text in enumerate(text_data["da_segmented_text"]): #check if i is sctually number


    da_segmented_sentences = ast.literal_eval(text_data.loc[i]["da_segmented_text"])

    sentece_entry = {}
    for p, sentence in enumerate(da_segmented_sentences):
        sentece_entry[p] = sentence
    
    paragraph_entry[i] = sentece_entry

# %%
paragraph_entry
# Out:
# {0: {0: 'Mødet er åbnet.',
#   1: 'I henhold til grundloven er Folketinget i dag  trådt sammen til sit første møde i det nye folketingsår.',
#   2: 'Som det medlem, der længst har været medlem af Tinget,  \xa0\xa0påhviler det mig, jf. Folketingets forretningsordens § 2,  stk. 3, at lede valget af Tingets Præsidium og  tingsekretærer.  \xa0\xa0\xa0\xa0\xa0Til formand for Folketinget har samtlige Tingets  medlemmer indstillet hr. Erling Olsen, Socialdemokratiet.',
#   3: 'Da  der således ikke foreligger andre indstillinger, vil jeg  betragte indstillingen som vedtaget.',
#   4: '(Ophold).',
#   5: 'Den er  vedtaget.',
#   6: 'Til næstformænd har Tingets fire største partier - ud  over det parti, som formanden tilhører - udpeget følgende  medlemmer:  \xa0\xa0\xa0\xa0\xa0Til første næstformand hr. Ivar Hansen, Venstre, til  anden næstformand hr. Henning Grove, Det Konservative  Folkeparti, til tredje næstformand fru Margrete Auken,  Socialistisk Folkeparti, og til fjerde næstformand fru  Elisabeth Arnold, Det Radikale Venstre.',
#   7: 'De pågældende er  herefter valgt.',
#   8: 'Til tingsekretærer er i henhold til de indgåede  valgforbund og gruppernes indstilling valgt følgende  medlemmer:  \xa0\xa0\xa0\xa0\xa0Fru Grete Schødts, Socialdemokratiet, hr. Ove Fich,  Socialdemokratiet, hr. Helge Sander, Venstre, og hr. Niels  Ahlmann-Ohlsen, Det Konservative Folkeparti.',
#   9: 'Tinget er hermed sat, og jeg beder den af Tinget valgte  formand indtage formandspladsen.',
#   10: 'Jeg ønsker Præsidiet held og lykke med arbejdet.'},
#  1: {0: 'Jeg vil gerne takke Tinget for den tillid, man har vist mig  ved at genvælge mig til formand.',
#   1: 'Jeg skal bestræbe mig på  efter bedste evne og i et tæt samarbejde med mine kolleger i  Præsidiet at opfylde de forpligtelser, der påhviler mig som  Tingets formand.',
#   2: 'Jeg byder velkommen til vore gæster i dag.',
#   3: 'Jeg byder  hjertelig velkommen til Hendes Majestæt Dronningen, til Hans  Kongelige Højhed Prinsen, til Hans Kongelige Højhed Kronprins  Frederik, til Hans Kongelige Højhed Prins Joachim, til Hendes  Kongelige Højhed Prinsesse Alexandra og til Hendes Kongelige  Højhed Prinsesse Benedikte.',
#   4: 'Jeg byder ligeledes hjertelig velkommen til  repræsentanterne for Højesteret, til formanden for Grønlands  Landsting og Grønlands landsstyreformand, til Færøernes  lagmand samt til formanden for Københavns  Borgerrepræsentation og Københavns overborgmester.',
#   5: 'Jeg benytter lejligheden til at sende Folketingets  hilsen på denne dag til Grønlands Landsting og Færøernes  Lagting.',
#   6: 'Politiske opgaver på Færøerne forhindrer desværre  formanden for Færøernes Lagting i at være til stede her i  dag.',
#   7: 'Herefter giver jeg ordet til statsministeren, for at han  kan give den i grundloven omhandlede redegørelse for rigets  almindelige stilling og de af regeringen påtænkte  foranstaltninger.'},
#  2: {0: 'For 25 år siden sagde et flertal i befolkningen ja til  Europa.',
#   1: 'For 8 år siden væltede folk i Østeuropa',
#   2: 'Berlinmuren',
#   3: 'til  det frie demokratiske Europa.',
#   4: '',
#   5: 'For 5 år siden var Danmark gået i stå med arbejdsløshed  og gældsætning, modløshed og indadvendthed.',
#   6: 'Der manglede  politisk vilje og tro på, at vi kunne forny og udvikle det  danske samfund.',
#   7: 'Tre stykker nyere historie.',
#   8: 'Tilsammen danner de afsæt  for nogle ganske afgørende beslutninger om Danmarks fremtid,  beslutninger, som vi skal træffe i løbet af denne samling.',
#   9: 'Vælger vi rigtigt og vælger vi ansvarligt, holder vi fast i  vore egne samfundsværdier, så kan vi give Danmark den bedst  tænkelige start på det 21. århundrede.',
#   10: 'Politik gør en forskel.',
#   11: 'På fire et halvt år er Danmark  som forvandlet.',
#   12: 'Danmark er nu i fremgang; vi har vist, at vi  godt kan.',
#   13: 'Vores vej - den danske vej - er ikke en kopi af  andres veje.',
#   14: 'Den er ikke kommet ved at efterligne eller ved  at ligge i læ af andre.',
#   15: 'Den er kommet, fordi vi ville det.',
#   16: 'Den er kendt, og den er respekteret i udlandet.',
#   17: 'Regeringen har fremlagt sin vision for Danmark år 2005.',
#   18: 'Vi vil ruste Danmark og hver enkelt borger til at klare sig i  det nye århundrede.',
#   19: '',
#   20: 'Regeringen er fast besluttet på at fastholde  fremgangslinien for Danmark, ikke alene til gavn for dem, der  kan selv, ikke alene til gavn for de fleste, men til gavn for  alle, for hele den danske befolkning.',
#   21: 'For hvad hjælper vel  det, at vi sikrer overskuddet på betalingsbalancen, hvis der  er underskud på samhørighed og på fællesskabsfølelse.',
#   22: 'For regeringen er der to overordnede beslutninger i  denne samling: for det første folkeafstemningen om  Amsterdamtraktaten, for det andet den nødvendige justering af  økonomien.',
#   23: 'Sammen med disse to overordnede beslutninger vil  regeringen tage en række initiativer, og jeg vil i min  redegørelse i dag samle mig om fem hovedområder, der er helt  centrale for vores hverdag:  \xa0\xa0\xa0\xa0\xa01.',
#   24: 'Kvalitet i den offentlige service.',
#   25: '2.',
#   26: 'Familiens trivsel og børnenes uddannelse.',
#   27: '',
#   28: '3. Bedre miljø og sunde fødevarer.',
#   29: '4.',
#   30: 'Et dynamisk erhvervsliv og arbejdsmarked.',
#   31: '',
#   32: '5.',
#   33: 'En konsekvent rets- og udlændingepolitik.',
#   34: 'Og nu til de to overordnede beslutninger:  \xa0\xa0\xa0\xa0\xa0I det store internationale billede har vi i de senere år  vist, at et lille land - vort land - godt kan gøre sig  gældende.',
#   35: 'Det er et land, der gør en forskel.',
#   36: "Det har været et travlt år for Danmark i  udenrigspolitikken, et år med mange milepæle: topmøder i EU,  i OSCE og i NATO og besøg af USA's præsident.",
#   37: 'Det var et år,  hvor dansk udenrigspolitik høstede stor anerkendelse.',
#   38: 'Også i kampen for menneskerettigheder vil Danmark  fortsat være i front; det har skabt stor respekt om Danmark i  verden.',
#   39: 'Her på fredag er der endnu et topmøde, vi skal  deltage i: Europarådets topmøde i Strasbourg om  menneskerettigheder.',
#   40: "FN's 52.",
#   41: 'generalforsamling afholdes i denne tid.',
#   42: 'Verden  har brug for et stærkt og effektivt FN.',
#   43: 'Det kræver reformer,  og det kræver økonomi.',
#   44: "Danmark har givet FN's generalsekretær  sin helhjertede og fulde støtte.",
#   45: "Blandt FN's mange opgaver skal jeg nævne, at FN især bør  fortsætte sin aktive linie for rydning af antipersonelminer i  krigsplagede lande, så flygtninge kan vende hjem og nye  flygtningestrømme kan undgås.",
#   46: 'Danmark har også været særdeles aktiv i udformningen af  en række initiativer, når det gælder internationale aftaler  om miljøet.',
#   47: "Nu gælder det om på FN's globale klimamøde i  Kyoto at formindske den menneskeskabte drivhuseffekt og  forbedre klodens klima.",
#   48: 'Også her vil Danmark være én af  frontløberne.',
#   49: 'Danmark har også været i front på den internationale  scene, når det gælder OSCE.',
#   50: 'Vi har i år haft formandskabet,  og vi har udfoldet et særdeles aktivt formandskab.',
#   51: 'OSCE har  bidraget afgørende til, at vi i Østeuropa nu kan holde en  række konflikter nede og forebygge andre.',
#   52: 'Albanien er jo det  gode eksempel.',
#   53: 'NATO-topmødet i Madrid tidligere på året var et  historisk vendepunkt, et vendepunkt for organisationens  bidrag til sikring af freden i Europa.',
#   54: "Et nyt fundament for  freden er skabt med beslutningen om NATO's udvidelse og den  historiske aftale mellem Rusland og NATO og mellem Ukraine og  NATO.",
#   55: 'I Østersøområdet er det regeringens ambition at følge  op og at se en nordeuropæisk region blomstre i kultur,  samfundsmønster, beskæftigelse og økonomi.',
#   56: 'Regeringen vil  bruge sit formandskab for Østersørådet i år til at sætte  yderligere skub i samarbejdet.',
#   57: 'Den største trussel mod freden i Europa er stadig  situationen i det tidligere Jugoslavien.',
#   58: 'Danske soldater gør  en stor og anerkendelsesværdig indsats.',
#   59: 'Hvis der bliver behov  for, at danske soldater bliver i Eksjugoslavien, også længere  end hidtil planlagt, så er regeringen positivt stemt herfor.',
#   60: 'Og så til det europæiske spørgsmål.',
#   61: 'I det kommende  folketingsår skal vi ved en folkeafstemning træffe beslutning  om Danmarks placering i Europa.',
#   62: 'Vi, regeringen, har lært af  folkeafstemningen den 2. juni 1992, og vi har lært af  folkeafstemningen den 18. maj 1993.',
#   63: 'Vi har lært, og vi har  lyttet.',
#   64: 'Danskerne vil godt være en del af Europa.',
#   65: 'Europa må også  godt være en del af Danmark, men også kun en del.',
#   66: 'For  regeringen var det derfor afgørende at nå et resultat i  Amsterdam, hvor den danske befolkning kunne genkende de  værdier, som samfundet i Danmark bygger på.',
#   67: 'Det lykkedes, det  lykkedes.',
#   68: 'Der er derfor tre grunde til, at regeringen vil anbefale  den danske befolkning at stemme ja ved den kommende  folkeafstemning.',
#   69: 'For det første: Amsterdamtraktaten er jo selve  forudsætningen, fundamentet for udvidelsen af EU til også at  omfatte landene i Øst- og Centraleuropa, ganske enkelt  forudsætningen for et fredeligt Europa, også for vore børn og  for vore børnebørn.',
#   70: 'For det andet:',
#   71: 'Amsterdamtraktaten er ganske enkelt bedre  end den, vi har.',
#   72: 'Den er et klart fremskridt for de danske  mærkesager: demokrati, menneskerettigheder, bedre samarbejde  om miljø og beskæftigelse, mærkesager, som vi jo deler i  Folketinget og i samfundet.',
#   73: 'For det tredje: De fire danske forbehold står intakte og  sikrede, som regeringen lovede den danske befolkning.',
#   74: 'Jeg  tror, at enhver kan erindre ordene »før, under og efter«.',
#   75: 'Sådan forholder det sig.',
#   76: 'Den ny traktat er jo at sammenligne med nye vedtægter  for en forening, men EU er ikke en forening, hvor vi skal  samarbejde om hvad som helst.',
#   77: 'Vi skal samarbejde om det  nødvendige.',
#   78: 'Vi skal samarbejde om lige præcis de spørgsmål,  som vi ikke kan løse hver for sig, hverken mere eller mindre.',
#   79: 'I den ny traktat er der klare holdninger og klare mål.',
#   80: 'Kampen mod arbejdsløsheden, ja, den er fortsat hvert enkelt  lands hovedansvar, men nu vil vi tage ved lære i fællesskab  af fortidens fejl.',
#   81: 'Vi vil undgå, at vi eksporterer  problemerne til hinanden i nedgangstider, og vi vil sikre, at  vi får mere beskæftigelse til gavn for os alle sammen i  opgangstider.',
#   82: 'På EU-topmødet i november tager vi fat i  praksis.',
#   83: 'Vi ved jo også godt, at syreregnen ikke standser i  Padborg.',
#   84: 'Gamle atomkraftværker i Østeuropa er ikke alene  deres problem, men er jo i virkeligheden også vort problem.',
#   85: 'Med de nye miljøbestemmelser i Amsterdamtraktaten kan vi  bedre bekæmpe den forurening, der kommer over grænserne, og  vi kan bedre sikre vores fælles miljø, for vores fælles miljø  er jo vores fælles ansvar.',
#   86: 'Allervigtigst, allervigtigst for Danmark og for vores  fremtid og for de andre landes fremtid, allervigtigst er, at  Amsterdamtraktaten betyder, at vi nu kan gå i gang med at  begynde opbygningen af et helt, et udelt Europa.',
#   87: 'Nu kan vi omsider give de øst- og centraleuropæiske  lande, herunder de tre baltiske lande, håndslag om et  kommende medlemskab.',
#   88: 'Ingen - og jeg gentager: ingen - skal  efterlades i usikkerhed.',
#   89: 'Vi skal på topmødet i december  træffe beslutning om, hvordan udvidelsesforhandlingerne skal  tilrettelægges.',
#   90: 'Der bliver ikke tale om en kvart udvidelse  eller en halv udvidelse.',
#   91: 'Der bliver tale om en hel  udvidelsesproces, om en sammenhængende proces, der vil  strække sig en hel del år ud i fremtiden.',
#   92: 'Danmark er forrest, når det gælder miljøstøtten til  Østeuropa, herunder også til de baltiske lande.',
#   93: 'Vi er det  land, der bidrager mest, og resultaterne både for dem og for  os har været imponerende.',
#   94: 'Ikke mindst i forbindelse med udvidelsen af EU er det  vigtigt, at ansøgerlandene lever op til miljøkravene, og det  vil Danmark hjælpe aktivt med til.',
#   95: 'Vi skal være med til at  sætte præg på udviklingen.',
#   96: 'Nærhedsprincippet står nu tydeligere end før.',
#   97: 'Der er  trukket en klarere streg mellem vores egen selvbestemmelse og  det, vi ønsker EU skal samle sig om.',
#   98: "EU's udvikling skal  fremover ske i en retning, som befolkningen føler sig tryg  ved, og hvor det er befolkningerne, der sætter tempoet.",
#   99: 'Et ja ved den kommende folkeafstemning vil tegne et  perspektiv for Danmark i Europa.',
#   100: 'Et nej vil sætte Danmark på  sidelinjen, og det ønsker regeringen ikke.',
#   101: 'Dér hører Danmark  ikke hjemme!',
#   102: 'Regeringen fremsætter allerede i dag lovforslag  om Danmarks tilslutning til Amsterdamtraktaten, og  folkeafstemningen vil finde sted torsdag den 28. maj 1998.',
#   103: 'Der bliver tid til en grundig debat, både her i Folketinget  og ikke mindst i befolkningen.',
#   104: 'Så til den anden overordnede beslutning, regeringen  lægger op til, nemlig økonomien.',
#   105: 'Danmark er i fremgang, og  håbet og troen på fremgangen er genskabt.',
#   106: 'Vi har vist, at et  flittigt folk er at finde i Danmark, når bare det får  chancen, og danske virksomheder har vist, at de har talent og  styrke til at gribe de nye udfordringer.',
#   107: 'Regeringen har gennem sin økonomiske politik - med bl.a.  reformerne af arbejdsmarkedet og skattesystemet - lagt nye,  bedre og mere stabile rammer til rette.',
#   108: 'Vi har fået en bedre  offentlig service med mindre tyngende offentlige udgifter, vi  har overskud på finanserne, renten og inflationen er  historisk lav, og der er overskud på betalingsbalancen.',
#   109: 'Men  det er ikke medvind udefra, der har bragt dansk økonomi i god  form.',
#   110: 'Vore største handelspartnere, Tyskland og Sverige,  halter bagud, og vi skal faktisk lede længe rundt i Europa  for at finde andre lande, hvor det går lige så godt som i  Danmark.',
#   111: 'Mange steder her i landet er der en situation, hvor  praktisk talt alle er i arbejde, og måske allerbedst: De  unges arbejdsløshed er nedbragt med to tredjedele.',
#   112: 'Hver gang  der for 4 år siden var 3 unge arbejdsløse, er der i dag kun  én, og om få år får vi heldigvis svært ved at finde den ene.',
#   113: "Den nye generation så at sige suges ind i uddannelse og  arbejde, og dagens unge stilles over for muligheder, som vi  skal tilbage til 1960'erne og de tidlige 1970'ere for at  finde magen til.  Med et Danmark i fremgang kan vi se ind i en fremtid,  hvor langt færre er henvist til passiv forsørgelse, og hvor  alle, der kan arbejde, faktisk kommer i arbejde.",
#   114: 'Det er det  afgørende, for det er jo betingelsen for, at vi kan få kraft  til hurtigt at nedbringe den gamle gæld.',
#   115: 'Vi har en stærk  pligt til at sikre, at den nye generations fremtid ikke skal  tynges helt urimeligt af gamle ubetalte regninger.',
#   116: 'Både  pengegælden og miljøgælden skal ned, og regeringen vil  kompromisløst fastholde den kurs, folket og regeringen har  slidt så hårdt for sammen med et flertal i Folketinget, og  som har givet så gode resultater.',
#   117: 'Men vil man holde retningen, skal man have en fast hånd  på rattet, og går det for hurtigt, må man lette foden lidt på  speederen.',
#   118: 'Det er derfor, regeringen i dag foreslår en  opstramning af finanspolitikken.',
#   119: 'Lige nu kører vi lidt for  hurtigt, og derfor vil vi - som vi hele tiden har sagt det -  ufortøvet justere den økonomiske politik, så vi holder ret  kurs og ret tempo.',
#   120: 'Vi må ikke, ja, vi vil ikke løbe selv den  mindste risiko for at ødelægge de gode tider, vi har fået  tilvejebragt i Danmark.',
#   121: 'Vi må forebygge i stedet for at reparere, når skaden er  sket.',
#   122: 'Vi vil ikke have inflationsspøgelset manet frem igen.',
#   123: 'Vi skal ikke skrue vort forbrug så hurtigt i vejret, at vi  mister overskuddet over for udlandet og dermed ikke kan få  udlandsgælden bragt ned, som vi har besluttet at gøre.',
#   124: 'Vi vil ikke tøve med at gøre det rigtige, men vi vil  ikke bringe os i en situation, hvor vi bliver tvunget til at  udløse dramatiske indgreb som kartoffelkuren i sin tid.',
#   125: 'Vi  husker jo alt for godt, hvordan titusinder af arbejdspladser  gik tabt, og vi husker, hvordan mange familier oplevede, at  deres hus gik på tvangsauktion.',
#   126: 'Vi har ikke brug for at bremse hårdt op.',
#   127: 'Der skal ikke  skæres i velstand og i velfærd, 1998 bliver stadig et endnu  bedre år end 1997, men tempoet i fremgangen skal være en  anelse mindre hektisk.',
#   128: 'Denne gang vil denne regering være på  forkant; den vil justere i tide, og den vil justere på en  socialt rimelig måde for at sikre beskæftigelsen også på  længere sigt.',
#   129: 'Vi vil ikke angribe menneskers muligheder for at blive i  deres bolig eller købe sig en bolig; men stigningen i både  det private og det offentlige forbrug i Danmark må dæmpes  næste år.',
#   130: 'Vi ved jo godt, at privatforbruget er langt den  største post i familien Danmarks budget, og det stiger lidt  for meget i øjeblikket.',
#   131: 'Derfor er der brug for, at danskerne  sparer lidt mere op.',
#   132: 'Regeringen vil derfor foreslå, at vi alle i 1998 lægger  1 pct. af lønnen til side til ekstra pensionsopsparing i  Arbejdsmarkedets Tillægspension.',
#   133: 'Det vil øge opsparingen med  4 mia. kr. For at dæmpe det lånefinansierede forbrug her og  nu foreslår regeringen desuden en midlertidig forhøjelse af  stempelafgiften på tillægslån i ejerboliger, og jeg vil gerne  understrege, at forhøjelsen ikke omfatter lån i forbindelse  med hussalg eller nybyggeri.',
#   134: 'Regeringen vil naturligvis også  på ny gennemgå statsbudgettet med tættekam.',
#   135: 'Her vil det være  vores mål at spare 2 mia. kr. ekstra, og endelig vil  regeringen foreslå opstramninger i arbejdsmarkedets  rådighedsregler samt en forenkling af voksen- og  efteruddannelsesområdet.',
#   136: 'Forslagene tilsammen vil ikke ramme de ydelser, der  retter sig mod børnefamilier, pensionister og syge.',
#   137: 'Regeringen vil afvise forslag om forringelser i kommunernes  økonomi, der bremser nødvendige forbedringer i sygehuse,  ældreomsorg, børnepasning og skole; men regeringen  forudsætter, at de kommunale udgifter næste år ikke udvikler  sig hurtigere, end det rent faktisk er aftalt i sommer.',
#   138: 'Regeringens nye initiativer skal ses i tæt sammenhæng  med det allerede fremsatte forslag til finanslov for 1998.',
#   139: 'For at opnå den nødvendige justering af den samlede økonomi  må også de budgetforbedringer, der er indarbejdet i  finanslovforslaget - herunder større arbejdsgiverforpligtelse  for sygedagpenge og justeringer af visse afgifter - indgå i  oplægget.',
#   140: 'Jeg vil nu vende mig til regeringens initiativer på de  fem hovedområder, jeg omtalte indledningsvis.',
#   141: 'For det første kvaliteten i den offentlige service:  »Danmark år 2005« er ikke en vision om at nedbryde  velfærdssamfundet og lade markedskræfterne klare det hele.',
#   142: 'Det er tværtimod en vision om et dansk velfærdssamfund, der  bringes ind i det nye århundrede i en ny, strømlinet og  livskraftig udgave med endnu flere i arbejde, endnu færre på  overførsler og langt, langt mindre gæld.',
#   143: 'De samlede offentlige udgifter tynger allerede nu langt  mindre i samfundets økonomi end for 4 år siden, især fordi  færre mennesker er henvist til at leve på  overførselsindkomst.',
#   144: 'De statslige driftsudgifter er ikke  vokset, og ved effektiv prioritering er der inden for  uændrede budgetter skabt plads til nye initiativer.',
#   145: 'Langt de fleste offentligt ansatte findes ude i kommuner  og amter og gør et godt arbejde for at levere  velfærdssamfundets kerneydelser: vuggestuer, børnehaver,  folkeskole, gymnasier, hjemmehjælp, sygehuse, plejehjem osv.',
#   146: 'Det er alt sammen områder, hvor danskerne har en berettiget  forventning om at få tilbudt service af ordentlig kvalitet.',
#   147: 'Men alt for stramme budgetter i årene frem til 1993 førte til  åbenbare servicebrist og uacceptable ventetider.',
#   148: 'Vi husker jo  alle sammen avisoverskrifterne og tv-reportagerne om de  utilfredsstillende forhold dengang.',
#   149: 'Derfor har kommunerne og  amterne i forståelse og samarbejde med regeringen i de sidste  4 år brugt flere penge og ansat flere folk i et storstilet  forsøg på at komme problemerne til livs.',
#   150: 'De sidste års udgiftsstigninger er imidlertid sket i et  tempo, der ikke kan fortsætte i de kommende år; det er der  enighed om mellem regeringen og de kommunale organisationer.',
#   151: 'Men det er samtidig lige så klart, at der i årene frem til år  2005 vil være vigtige nye opgaver, der skal løses, og at der  skal gennemføres de nødvendige serviceforbedringer inden for  det offentlige.',
#   152: 'Derfor må vi overalt i det offentlige skærpe  vor opmærksomhed over for, om kræfterne og pengene nu bruges  på den rigtige måde: Er der stiv organisation?',
#   153: 'Er der  bureaukratisk tankegang?',
#   154: 'Så skal der råbes op!',
#   155: 'Det helt  overordnede hensyn må være, at borgerne altid får kvalitet,  får valuta for deres skattekroner; men det får de kun, når  medarbejdernes talenter bruges bedst muligt, og når  medarbejderne har inspirerende arbejdsvilkår.',
#   156: 'Folketinget bør ikke blande sig i, hvordan kommunerne  løser deres opgaver.',
#   157: 'Folketinget bør alene fastholde, at det  er kommunernes folkevalgte, der har det politiske ansvar for  finansiering, for lige adgang, for kortere ventetid, for  kvalitet og for valgmuligheder.',
#   158: 'Det er dem, der må vurdere,  om private leverandører kan yde borgerne en bedre service,  end det kommunale system kan.',
#   159: 'Vi må lære af hinanden på  tværs, vi må lære af hinanden, også det offentlige og de  private imellem.',
#   160: 'Men, men, men - selv med den mest vellykkede fornyelse  af den offentlige service - og vi lærer af hinanden - findes  der intet mirakel, der, som jeg har hørt det fremhævet fra  visse sider, på kort sigt kan fremtrylle nye tocifrede  milliardbeløb i besparelser.',
#   161: 'Der findes kun to måder: enten  ved voldsomme nedskæringer - og det ønsker regeringen ikke -  eller ved brugerbetaling på nøgleområder som sundhed,  uddannelse og ældreomsorg.',
#   162: 'Det ønsker regeringen heller ikke!',
#   163: 'Sandheden skal frem: Løfter om store skattelettelser er  derfor enten en trussel om, at den private pengepung skal  betale for det, der i dag betales over skatter og afgifter,  eller også er det et katastrofalt bidrag til på ny at slå hul  på samfundets kasse.',
#   164: 'Vore sygehuse skal fungere godt, og de skal fungere uden  lange ventetider.',
#   165: 'Amterne har i de sidste 4 år satset store  midler på at nærme sig dette mål.',
#   166: 'Meget er investeret i ny  teknik og moderne behandlingsmetoder, og samtidig er der  kommet bedre information og muligheder for at bestille »tid  til behandling«, det såkaldte bookingsystem.',
#   167: 'Vi ser nu de  begyndende resultater i form af kortere ventetider til  behandling og til operation.',
#   168: 'Det frie sygehusvalg i det offentlige er så småt begyndt  at blive en realitet, og vi skal videre ad den vej, så de  mennesker, der ønsker hurtigere behandling, kan få det ved at  opsøge et andet sygehus, hvor ventetiden er kortere.',
#   169: 'Vi skal  ikke slappe af, før sygehusenes problemer er løst, og derfor  vil regeringen følge op på Sygehuskommissionens arbejde med  analyser af vore sygehuse som serviceenheder.',
#   170: 'Det vil  naturligvis ske i samarbejde med sygehusejerne.',
#   171: 'Er kvaliteten  og produktionen tilfredsstillende?',
#   172: 'Er det den rigtige  ledelsesmåde, vi anvender?',
#   173: 'Er samspillet mellem de enkelte  personalegrupper, som det skal være?',
#   174: 'Regeringen vil drøfte  resultaterne af en sådan analyse og mulige initiativer med  amterne, sygehusledelserne og personaleorganisationerne.',
#   175: 'Når man bliver indlagt på et hospital, er man ofte bange  og bekymret, og man er selvsagt sårbar i sådanne situationer.',
#   176: 'Men patienterne har også rettigheder, og derfor vil  regeringen fremsætte et samlet lovforslag, som bringer  klarhed, som samler, klargør og styrker patienternes  retsstilling på hospitalet.',
#   177: 'Det handler jo om selvværd, det  handler om respekt for den enkelte, og det handler om  kvalitet.',
#   178: 'I politik plejer vi at tale om en række områder, og  desværre plejer vi også at anvende dette udtryk om mennesker  - i dette tilfælde mennesker, som kræver særlig opmærksomhed,  mennesker, som vi skylder at indfri løfterne til, mennesker,  som har sårede og sårbare sind.',
#   179: 'Både omsorgen for de psykiatriske patienter, de fysiske  rammer på sygehusene og botilbudene har ikke været  tilstrækkelige.',
#   180: 'Nu er vi omsider efter års indsats begyndt at  komme på rette vej - igen som et resultat af et godt  samarbejde mellem stat, amter og kommuner.',
#   181: 'Ret vej er ikke  hele vejen.',
#   182: 'Retningen er sat, og vi skal fortsætte ad den vej  i årene, der kommer.',
#   183: 'De ældre har krav på, at sundhedsvæsenet fungerer, og at  der er god forsyning af ældrevenlige boliger.',
#   184: 'Siden 1993 er  det samlede antal ældreboliger vokset.',
#   185: 'Vi har satset  målrettet netop på flere ældreboliger for at give vore ældre  mulighed for at opretholde en tilværelse, der ligger så tæt  som muligt op ad den tilværelse, de hidtil har kendt.',
#   186: 'Men for at det skal lykkes, skal vore ældre også have  ordentlig hjælp i deres hjem til rengøring, til praktiske  gøremål og til mere personlige ting.',
#   187: 'Hjælpen skal være vel  tilrettelagt.',
#   188: 'Det er vigtigt, at det, der bliver lovet, også  bliver holdt.',
#   189: 'Men der er meget stor forskel på, hvor godt  hjemmehjælpen er organiseret ud over landet.',
#   190: 'Det kan de ældre  ikke være tjent med.',
#   191: 'Regeringen ser positivt på, at der  nu lokalt tilbydes de ældre valgmuligheder, når det gælder  praktisk hjælp i hjemmet.',
#   192: 'Så til det andet store område: Familiens trivsel og  børnenes uddannelse.',
#   193: 'Familieliv og arbejdsliv skal hænge  bedre sammen.',
#   194: 'Det er godt for børnene, at deres forældre har  arbejde, men det forhold, at mange flere småbørnsforældre er  kommet i arbejde i de senere år, er en stor del af  forklaringen på den voldsomme vækst i efterspørgslen, vi har  set, efter offentlig børnepasning.',
#   195: 'Der er i årene 1993-97 skaffet ekstra 130.000  børnepasningstilbud i danske kommuner.',
#   196: 'Kommunerne har faktisk  udrettet mere, end vi for fire år siden troede var nødvendigt  for fuld dækning af behovet, men der er endnu et stykke vej  til målet.',
#   197: 'Vi ved også godt, at mange småbørnsfamilier har brug for  en mindre stresset hverdag.',
#   198: 'Regeringen vil derfor opfordre  arbejdsmarkedets parter til at drøfte en udvidelse af  adgangen til deltidsarbejde for ansatte med små børn.',
#   199: 'Regeringen vil som bidrag til større ligestilling i  ansvaret for småbørnene komme med forslag om en to ugers  forlængelse af barselorloven for mænd.',
#   200: 'Regeringen vil med  arbejdsmarkedets parter drøfte mulighederne for en  smidiggørelse af børnepasningsorloven og drøfte en ændring af  funktionærloven, så gravide får adgang til fuld løn under  sygdom.',
#   201: 'På de statslige arbejdspladser vil der blive givet  tilbud om adgang til hjemmearbejdspladser.',
#   202: 'Større hensyn til familiernes behov vil i sig selv  fremme ligestillingen mellem kvinder og mænd, og som led i  styrkelsen af ligestillingen vil regeringen også forslå at  ændre pensionslovgivningen, sådan at kvinder og mænd får  udbetalt den samme årlige pensionsydelse.',
#   203: 'Børnene er nøglen til fremtiden.',
#   204: 'Skolen er nøglen til  børnenes fremtid.',
#   205: 'Vores fremtid afgøres derfor i høj grad af,  hvordan skolen er nu.',
#   206: 'Regeringen har - inden for de gode  rammer, folkeskolen angiver - igangsat en lang række  initiativer og forsøg med at gøre tingene anderledes, end vi  plejer.',
#   207: 'Lærere, forældre, kommuner, politikere - alle har vi  et ansvar for kvaliteten i folkeskolen; alle er vi optaget  af, at børnene lærer at læse, lærer at skrive, lærer at  regne, og at de lærer at bruge en computer.',
#   208: 'Vi kan ikke være bekendt at give vore børn mindre end  det bedste.',
#   209: 'Vi skal ruste dem alle til at uddanne sig videre,  og vi er på rette vej.',
#   210: 'For aldrig før har en så stor del af  en ungdomsårgang været i gang med en uddannelse.',
#   211: 'Der er skabt  flere pladser på gymnasier, på erhvervsskoler, på  universiteter og på læreanstalter.',
#   212: 'Otte ud af ti er nu i  gang.',
#   213: 'I år 2000 er det vores mål, at det er ni ud af ti.',
#   214: 'Regeringens mål er et tilbud om en god ungdomsuddannelse  til alle, uanset om man nu vælger fagligt, teoretisk eller en  kombination deraf.',
#   215: 'Vi vil inspirere til, at flere vælger en  faglig uddannelse; ellers bliver der jo mangel på håndværkere  på fremtidens arbejdsmarked.',
#   216: 'Regeringen vil i efteråret indlede trepartsdrøftelser  med arbejdsmarkedets parter.',
#   217: 'Vi forventer, at parterne også  ved forårets overenskomstforhandlinger vil vise ansvarlighed,  som de har gjort det hidtil, så vi kan fastholde moderate  omkostningsstigninger og skabe flest mulige nye ekstra job.',
#   218: 'Vi skal drøfte, hvordan vi i fællesskab kan fremme  udviklingen af et rummeligt arbejdsmarked, hvor mennesker med  nedsat arbejdsevne kan fastholde eller genvinde  beskæftigelsen.',
#   219: 'Vi skal give plads for dem, der endnu ikke  har fået en chance.',
#   220: 'Det handler om, at virksomhederne i højere grad skal  påtage sig et socialt ansvar.',
#   221: 'Det handler også om »projekt  arbejdspladsfastholdelse«, som er vigtigt som initiativ, og  vi har allerede gode erfaringer hermed.',
#   222: 'Fleksjobbene skal  udbredes som et positivt alternativ til, at alt for mange  henvises til førtidspension.',
#   223: 'Så skal vi også enes om en aktiv seniorpolitik, vi skal  tilskynde til et senere og mere gradvist  tilbagetrækningsmønster.',
#   224: 'Og heldigvis får arbejdspladserne jo  også i stigende grad brug for at bevare de ældres erfaringer.',
#   225: 'Derfor skal vore ældre have reelle muligheder for at gå ned i  arbejdstid frem for helt at trække sig tilbage fra  arbejdsmarkedet.',
#   226: 'Men et langt og et godt arbejdsliv bliver jo altså kun  en virkelig realitet med et ordentligt arbejdsmiljø.',
#   227: 'Arbejdsmiljøet er stadig væk ikke godt nok.',
#   228: 'Der sker fortsat  nedslidning og alt, alt for mange ulykker på danske  arbejdspladser.',
#   229: 'Jeg vil meget indtrængende opfordre danske  virksomheder og arbejdsmarkedets parter til at prioritere  arbejdsmiljøindsatsen meget højere.',
#   230: 'Vi skal også være  foregangsland på dette område.',
#   231: 'I sidste folketingssamling fik regeringen vedtaget de  lovforslag, der udmønter dele af handlingsprogrammet »',
#   232: 'Rent  arbejdsmiljø år 2005«.',
#   233: 'Den indsats vil blive forstærket nu.',
#   234: 'Der indføres en belønningsordning for virksomheder, der gør  en særlig ekstraindsats ud over det, loven stiller krav om,  for at forbedre arbejdsmiljøet.',
#   235: 'Regeringen vil også fortsætte sin offensive  miljøpolitik.',
#   236: 'Det er vores næste store felt.',
#   237: 'Vi har alle et  ansvar for, at vi ikke videregiver en negativ miljøarv til  vore børn og vore børnebørn.',
#   238: 'Beskyttelsen af vandmiljøet og  grundvandet skal være bedre.',
#   239: 'Vi vil ikke acceptere, at  drikkevandet forurenes og vore fjorde dør af iltsvind.',
#   240: 'Reguleringen af landbrugets brug af gødning har ikke været  god nok.',
#   241: 'Der skal ske en bedre udnyttelse af husdyrgødningen,  og naturgenopretningen skal forstærkes.',
#   242: 'Regeringen vil i dette folketingsår fremsætte forslag om  indførelse af en kvælstofafgift.',
#   243: 'Der er gjort meget, men der  er ikke gjort nok.',
#   244: 'Regeringen har de to sidste år forbudt 170  af de mest miljøbelastende pesticider, men vi har ikke nået  målene i pesticidhandlingsplanen.',
#   245: 'Der er derfor behov for at  stramme op.',
#   246: 'Regeringen vil fremsætte lovforslag om en mærkbar  forhøjelse af pesticidafgiften.',
#   247: 'Bæredygtigt landbrug, rent vand og sunde fødevarer er  tre sider af samme sag.',
#   248: 'Danmark skal være foran med  kvalitetskravene.',
#   249: 'Regeringen vil i denne samling lægge  fundamentet for en ny og forenklet fødevarelovgivning.',
#   250: 'Det  skal styrke kvalitetsarbejdet, og det skal skabe  gennemsigtighed i produktionen.',
#   251: 'Forbrugerne skal kunne stole på, at de fødevarer, de  køber, er sunde og rene.',
#   252: 'Vi vil ikke acceptere  sygdomsfremkaldende bakterier i vores mad.',
#   253: 'Kvaliteten af vore  fødevarer afhænger også af dyrenes adfærd og velfærd.',
#   254: 'Forbruget af medicin skal reduceres.',
#   255: 'Regeringen vil skærpe  kontrollen med forbruget af veterinær medicin.',
#   256: 'Ser vi på vores erhvervsliv og vores arbejdsmarked, kan  vi jo se et arbejdsmarked i Danmark, der fungerer langt mere  smidigt end andre steder i Europa og meget bedre end for få  år siden.',
#   257: 'Det er en meget væsentlig del af baggrunden for en  enestående stærk fremgang i dansk beskæftigelse - en  fremgang, vi hidtil har kunnet forene med lav inflation.',
#   258: 'Vi har bevaret - og vi vil bevare - et godt  dagpengesystem, som ikke bare giver lønmodtagerne økonomisk  tryghed under ledighed, men også, og det skal man huske,  fritager virksomhederne for omkostninger ved lange  opsigelsesvarsler, som vi kender det i andre lande.',
#   259: 'Arbejdsmarkedsreformerne har givet mennesker tryghed og  styrke i forandringen med klare rettigheder og pligter for de  ledige til at komme i gang igen.',
#   260: 'Vi har massivt øget indsatsen for efteruddannelse og  igangsætning af de ledige.',
#   261: 'Ungeindsatsen har været en entydig  succes.',
#   262: 'Indsatsen over for de langtidsledige er blevet stadig  mere ambitiøs og med resultater.',
#   263: 'Kortvarig og ofte  perspektivløs jobtræning erstattes nu mere og mere af  uddannelse og af puljejob, der har perspektiv både for den  enkelte og for samfundet.',
#   264: 'Et enkelt eksempel er den indsats,  der nu er gået i gang, med at sørge for medarbejdere, der kan  hjælpe med overvågning på stationer og i S-tog.',
#   265: 'Med den nye og langt bedre beskæftigelse i vort samfund  er der brug for, at den enkelte er parat til at bevæge sig,  tage nye udfordringer op, flytte branche, køre eller flytte  lidt længere efter nye jobmuligheder.',
#   266: 'Og med Danmark i  fremgang oplever vi stadig mangel på bestemte kvalifikationer  nogle steder, samtidig med at der er høj ledighed andre  steder.',
#   267: 'Regeringen vil derfor foreslå, at ledige fremover efter  seks måneder kan anvises og skal søge et rimeligt arbejde  også uden for deres hidtidige fagområde.',
#   268: 'Regeringen foreslår også justeringer i reglerne om  geografisk mobilitet, flyttehjælp, dimittender og aktivering.',
#   269: 'Etableringsydelsen skal afskaffes, og endelig vil vi sikre,  at lediges brug af uddannelsesorlov i højere grad kobles til  en handlingsplan, der styrker deres muligheder for at komme i  ny beskæftigelse igen.',
#   270: 'Regeringen ønsker, at efteruddannelsesmulighederne så på  den anden side forenkles og udnyttes endnu bedre.',
#   271: 'Derfor  foreslår vi, at brugerbetalingen på faglige efteruddannelser,  AMU-kurser, skal afskaffes.',
#   272: 'Vi vil opfordre arbejdsgiverne til at tænke mere  langsigtet og tænke mere offensivt og derfor bruge  uddannelsesorloven langt mere til at opkvalificere deres egne  medarbejdere.',
#   273: 'Dansk erhvervsliv har jo i de seneste år haft stærk  fremgang.',
#   274: 'Næsten 100.000 flere medarbejdere, stærkt  forbedrede overskud, rekordhøje aktiekurser og et rekordlavt  antal konkurser er det synlige resultat.',
#   275: 'Fremgangen er udtryk for god og fremsynet ledelse i  vældig, vældig mange virksomheder.',
#   276: 'Men fremgangen er også et  produkt af en økonomisk politik, der har understøttet  erhvervenes behov for god markedsudvikling, rolig  lønudvikling, lav rente, veluddannede medarbejdere, et godt  forskningsmiljø, en aktiv erhvervspolitik og god udbygning af  infrastrukturen.',
#   277: 'Derfor har regeringen besluttet gennem de seneste år at  iværksætte en række initiativer til at mindske de  administrative byrder for virksomhederne.',
#   278: 'Især mindre  virksomheder har jo fået afskaffet en lang række gebyrer og  afgifter.',
#   279: 'Nu iværksætter regeringen et nyt projekt, der inden  udgangen af 1998 vil sikre, at virksomhederne kan overgå til  elektronisk indberetning af års- og skatteregnskaber og andre  statistiske oplysninger, og samtidig vil regeringen give  mindre virksomheder en betydelig administrativ aflastning: et  tilbud om at etablere let og billig adgang til at overdrage  administrative opgaver til særlige servicevirksomheder.',
#   280: 'Vi vil styrke samarbejdet mellem virksomheder og  forskningsinstitutioner, ikke mindst for at styrke Danmarks  placering på informationsteknologiområdet, og vi vil forøge  indsatsen på de videregående IT-uddannelser i samarbejde med  erhvervene.',
#   281: 'Ser vi på vores rets- og udlændingepolitik, har borgerne  krav på effektiv retshåndhævelse.',
#   282: 'Samfundet skal derfor  rustes tilstrækkeligt til en effektiv indsats, hvad enten det  gælder rockere, narko, gadebander, grov vold, simpelt tyveri,  selskabstømning, bagmandsvirksomhed eller miljøforbrydelser.',
#   283: 'Politiet skal have styrke og teknologi til synligt og  effektivt at bidrage til borgernes tryghed og kriminalitetens  bekæmpelse.',
#   284: 'Hvor der er stigende problemer, skal der også  være en ekstra politiindsats og en hurtig strafforfølgning.',
#   285: 'Siden flerårsaftalen fra 1995 har politiet fået  uforudsete og arbejdskrævende ekstra opgaver.',
#   286: 'Regeringen vil  derfor invitere forligspartierne til en forhandling om  justering af politiaftalen.',
#   287: 'Regeringen vil samtidig tage initiativ til den fornødne  udbygning af fængslerne, så de »negativt stærke fanger« kan  isoleres på betryggende måde.',
#   288: 'Domstolenes uafhængighed og særlige stilling skal  styrkes.',
#   289: 'Forslaget til en omfattende domstolsreform vil  derfor blive genfremsat allerede i næste uge.',
#   290: 'Det gælder også  regeringens forslag om større åbenhed omkring dommernes  bijob.',
#   291: 'Justitsministeren vil afgive en redegørelse til  Folketinget om reduktion af ventetider inden for  retssystemet.',
#   292: 'Så er der offentlighedsprincippet, som desværre i nogle  situationer er blevet misbrugt - misbrugt til at forfølge og  chikanere offentligt ansatte.',
#   293: 'Regeringen vil fremsætte lovforslag, der begrænser  aktindsigten i personalesager for at skabe større  retssikkerhed for de ansatte, og det gælder for offentligt  som for privat ansatte.',
#   294: 'Fordi man er offentligt ansat, skal  man ikke være offentligt udhængt.',
#   295: 'Regeringen vil fastholde en flygtningepolitik, der  bygger på både humanisme og konsekvens.',
#   296: 'Vi skal helt i  overensstemmelse med vore internationale pligter tage imod  dem, der kommer hertil på flugt fra borgerkrig og forfølgelse  i deres eget land, men jo mere vi kan give en håndsrækning  til fred og fremgang i deres eget hjemland, og jo mere vi kan  bane dem vejen for i sikkerhed at kunne vende tilbage, desto  flere kan vi hjælpe på bedste vis.',
#   297: 'Vi skal med endnu større effektivitet bekæmpe  menneskesmugling og forhindre illegal indvandring fra sikre  lande, og til dem, der får lovligt ophold her i landet, skal  vi i deres egen interesse, i vores fælles interesse, stille  større krav.',
#   298: 'Lad os sige det, som det er: Den hidtidige integration  af udlændinge har ikke været god nok.',
#   299: 'Der har i alt for høj  grad været tale om klientgørelse og passiv forsørgelse.',
#   300: 'Regeringen vil fremsætte forslag til en helt ny  integrationslov, der både omfatter flygtninge og nye  familiesammenførte indvandrere.',
#   301: 'Sigtet er, at de nyankomne  får ret og pligt til at finde en plads på arbejdsmarkedet og  klare sig selv.',
#   302: 'Der skal bruges flere penge på at få  flygtninge og indvandrere i arbejde og færre på underhold.',
#   303: 'Vi overvejer at gøre permanent opholdstilladelse til  noget, der ikke gives automatisk efter 3 år, men noget, man  skal kvalificere sig til gennem en målrettet indsats: ved at  integrere sig i det danske samfund, ved at lære sproget, ved  at undgå at stifte større gæld til det offentlige og undgå  kriminalitet.',
#   304: 'Det enkelte menneske, den enkelte udlænding vil opleve,  at der stilles krav i Danmark, men man vil også opleve, at  det skaber forudsætningen for et langt mere positivt syn på  de udlændinge, der får permanent opholdstilladelse i Danmark.  Alt dette skal naturligvis ske med fuld respekt for  personlige, kulturelle og religiøse forskelle.',
#   305: 'Ret og pligt i udlændingepolitikken betyder også, at vi  skal bekæmpe den modvilje, der møder indvandrere på det  danske arbejdsmarked.',
#   306: 'Fordi man har et fremmed navn, behøver  man ikke at have svært ved at få arbejde.',
#   307: 'Regeringen har taget initiativ til, at statens  arbejdspladser lever op til deres ansvar, men det er  naturligvis helt afgørende, at også de private virksomheder  og kommunerne udviser fantasi, åbenhed og tolerance over for  folk med anderledes baggrund og et anderledes navn.',
#   308: 'Rigsfællesskabet: Regeringen lægger vægt på et nært og  et tillidsfuldt samarbejde mellem alle dele af  rigsfællesskabet.',
#   309: 'Vi glæder os over, den færøske økonomi  gennem de seneste par år har gennemgået en på flere punkter  meget positiv udvikling.',
#   310: 'Indkomsterne har været stigende,  arbejdsløsheden har været faldende, og som noget meget, meget  vigtigt for Færøerne er udvandringen vendt, og landskassen  havde i 1996 overskud.',
#   311: 'Der budgetteres nu også med overskud i  1997 og i 1998.',
#   312: 'Regeringen glæder sig over den positive udvikling, som  vi håber vi kan videreføre i årene fremover.',
#   313: 'Regeringen ønsker det nytiltrådte grønlandske landsstyre  held og lykke med det forestående arbejde.',
#   314: 'Grønland har i de  seneste år været præget at stor økonomisk stabilitet trods en  betydelig følsomhed over for ændringer i fiskeriet.',
#   315: 'Råstofforvaltningen skal efter aftale mellem regeringen  og landsstyret overdrages til Grønlands hjemmestyre - en  historisk aftale.',
#   316: 'Administrationen flyttes til Nuuk under  landsstyrets ansvar.',
#   317: 'Regeringen håber, at der fremover vil  vise sig store muligheder på råstofområdet til gavn for  beskæftigelsen og til gavn for indkomsterne for Grønland og i  Grønland.',
#   318: 'Vi ved helt sikkert, at store forandringer sker i vort  samfund, men vi ved også, at fremskridt forstået som  forandring til noget bedre er noget, vi selv skal kæmpe for.',
#   319: 'Hvis vi som ansvarlige politikere skal bevare befolkningens  tillid, skal vi vise vilje til at finde nye og bedre svar.',
#   320: 'Jeg har redegjort for vores visioner i dag, for vores  mål for Danmark år 2005 og for den kurs, regeringen vil  insistere på for at nå disse mål.',
#   321: 'Vi har talt om fem plus to vigtige områder for vores  fælles fremtid.',
#   322: 'To overordnede, en europæisk og en økonomisk  dansk, og fem hovedområder, der betyder så meget for  danskeres hverdag.',
#   323: 'Vi har talt om, hvorfor vi skal sætte farten en anelse  ned for at nå sikkert videre frem til vort mål.',
#   324: 'Det er  afgørende for regeringen, at vi fastholder helheden og det  rigtige tempo i de nødvendige beslutninger.',
#   325: 'Viljen til at  gøre det nødvendige er jo også politik.',
#   326: 'Regeringen vil ikke lade sig lamme af taktiske manøvrer  og uansvarlige meldinger fra anden side, for  handlingslammelse får jo bare små problemer til at vokse sig  store og alvorlige problemer til at forblive uløste.',
#   327: 'I en  situation, hvor der er behov for en vis justering i  forbruget, nytter det ikke at komme med store løfter om  skattelettelser, som der ikke er dækning for, eller med  forslag om ensidige nedskæringer over for samfundets dårligst  stillede, bl.a. dem på pension, efterløn eller dagpenge.',
#   328: 'Den  økonomiske udfordring, vi nu står over for, må ikke misbruges  til ideologiske skoleridt.',
#   329: 'Der er en opgave, og den skal  løses ordentligt og med fornuft, så de sidste 5 års  fremgangslinje kan fortsætte.',
#   330: 'Befolkningen har betroet os, Folketing og regering, et  meget stort ansvar.',
#   331: 'Lad os nu ikke svigte dette ansvar.',
#   332: 'Regeringen har som mindretalsregering opnået alle sine  resultater i samarbejde med andre.',
#   333: 'Det er vi os meget  bevidst, for samarbejdslinjen er jo den danske vej, og hvis  målene skal nås, skal der samarbejdes mellem partier i  Folketinget, mellem regering og kommuner og mellem  virksomheder og samfund.',
#   334: 'Danmark er i fremgang.',
#   335: 'Det skal vi fastholde.',
#   336: 'Må jeg foreslå, at vi indleder Folketingets arbejde med  at udbringe et leve for Danmark.',
#   337: '',
#   338: 'Danmark',
#   339: 'leve!      (Statsministerens opfordring besvaredes med et trefoldigt  hurra).',
#   340: '(Statsministerens redegørelse i henhold til grundlovens § 38   (skriftlig del)      I denne skriftlige del af redegørelsen gives en kortfattet  omtale af de lovforslag og forslag til folketingsbeslutning,  som regeringen ved begyndelsen af det nye folketingsår  forventer at fremsætte i løbet af folketingsåret.',
#   341: 'Denne del  af åbningsredegørelsen indeholder endvidere oplysninger om  ministerredegørelser til Folketinget.',
#   342: 'De med (X) markerede lov- og beslutningsforslag  forventes fremsat inden den 15. november 1997.',
#   343: 'ARBEJDSMINISTEREN      Ændring af lov om arbejdsløshedsforsikring  (X)',
#   344: 'Lovforslaget fremsættes med henblik på at ændre reglerne om  indbetaling af medlemsbidrag m.v. samt tilsyns- og eventuelt  klagereglerne.',
#   345: 'Forslaget er bl.a. en opfølgning på  folketingsbeslutning af 15. maj 1997 (B 82) om øget  gennemskuelighed af arbejdsløshedskassernes  administrationsomkostninger.',
#   346: 'Ændring af lov om seniorydelse  (X)',
#   347: 'Lovforslaget omfatter konsekvensrettelser som følge af, at  50/50-stillinger efter bistandslovens §',
#   348: '§ 91-95 ændres til  fleksjob med henholdsvis 1/3, ½ eller 2/3 løntilskud.',
#   349: 'Lov om støtte til handicappede i erhverv',
#   350: 'Forslaget skal bl.a. ses som et led i indsatsen for at skabe  et rummeligt arbejdsmarked.',
#   351: 'Loven samler de gældende regler  for støtte til handicappede inden for Arbejdsministeriets  område, bl.a. reglerne om personlig assistance til  handicappede i erhverv, handicappede ansøgeres fortrinsadgang  ved ansættelse hos offentlige arbejdsgivere, bevilling til  stadepladser og taxikørsel.',
#   352: 'Der forventes også fastsat regler  om arbejdspladsindretning samt eventuelt andre regler, der  tager sigte på at få handicappede i ordinær beskæftigelse  eller i skånejob/fleksjob.',
#   353: 'Ændring af lov om arbejdsmiljø (Belønningsordning m.v.)  (X)      Formålet med forslaget er at gennemføre ændringer af  arbejdsmiljøloven i forbindelse med indførelse af en  belønningsordning for virksomheder, der gør en særlig indsats  for at forbedre arbejdsmiljøet.',
#   354: "Med forslaget sikres  endvidere et uændret provenu til Arbejdsmiljørådets og  branchemiljørådenes indsats i forbindelse med gennemførelsen  af EU's 3. skadesforsikringsdirektiv.",
#   355: 'Lovforslaget skal ses i  sammenhæng med socialministerens forslag om ændring af lov om  forsikring mod følger af arbejdsskade og lov om  forsikringsvirksomhed og forventes fremsat samtidig hermed.',
#   356: 'Ændring af lov om aktiv arbejdsmarkedspolitik, lov om  arbejdsløshedsforsikring m.v., lov om orlov, lov om  arbejdsmarkedsuddannelser og lov om kommunal aktivering  (X)',
#   357: 'Der gennemføres en række arbejdsmarkedspolitiske initiativer,  der øger mobiliteten og fleksibiliteten på arbejdsmarkedet.',
# ...
#   29: 'På lidt længere sigt vil de internationale  bestræbelser og det internationale pres forhåbentlig føre  til, at de modvillige lande i stigende omfang tager egne  statsborgere tilbage.',
#   30: 'De internationale bestræbelser på en fælles løsning af  tilbagetagelsesproblemet skal imidlertid ikke afholde os fra  at søge egne løsninger på akutte udsendelsesproblemer.',
#   31: 'En af  måderne at gøre det på er at indgå bilaterale aftaler om  tilbagetagelse.',
#   32: 'Min forgænger har for nylig i Folketingets  Retsudvalg haft lejlighed til at redegøre for de  forhandlinger, vi aktuelt fører med Forbundsrepublikken  Jugoslavien om en tilbagetagelsesaftale.',
#   33: 'I 1997 har der været  drøftelser mellem Danmark og Forbundsrepublikken Jugoslavien  med henblik på at indgå en tilbagetagelsesaftale.',
#   34: 'Det har  ikke været en problemfri proces, kan jeg hilse og sige.',
#   35: 'På det første og hidtil eneste møde i maj 1997 enedes de  to lande om at udveksle aftaleudkast.',
#   36: 'Et dansk udkast  fremsattes i begyndelsen af juni.',
#   37: 'Først den 6. oktober modtog  Udenrigsministeriet et jugoslavisk udkast, og på det grundlag  vil forhandlingerne blive fortsat.',
#   38: 'Et andet eksempel på tilbagetagelsesaftaler er de  aftaler, som vi har indgået med myndigheder i Nordøst- og  Nordvestsomalia denne sommer.',
#   39: 'Baggrunden for disse aftaler  var, at Flygtningenævnet i sager, hvor der ville blive  meddelt afslag på asyl, havde bestemt, at tvangsmæssig  udsendelse forudsætter indgåelse af tilbagetagelsesaftaler  med de stedlige myndigheder.',
#   40: 'Derudover må vi konstatere, at Nordøst- og  Nordvestsomalia efter mange års borgerkrig er meget hærget og  meget ødelagt.',
#   41: 'Disse områder er da dermed heller ikke parate  til at modtage de hundredtusindvis af flygtninge, der  befinder sig både i nærområdet og spredt ud over det meste af  verden.',
#   42: 'En sådan massiv repatriering vil bringe den  stabilitet, der nu er opnået i området, i fare.',
#   43: 'Regeringens opfattelse, som deles af en lang række  internationale humanitære organisationer, var, at en mere  massiv tvangsmæssig tilbagesendelse af personer til områderne  burde følges op af hjælp til genopbygning.',
#   44: 'For regeringen var  det således naturligt at vurdere, om Danmark kunne hjælpe til  på disse områder ved at benytte midlerne fra miljø- og  katastroferammen til at supplere den humanitære bistand, som  vi allerede yder til Somalia.',
#   45: 'Der var hverken tale om støtte  til den enkelte ansøger eller om penge til de stedlige  myndigheder, men støtte til internationalt arbejde, til  hjælpe- og udviklingsorganisationernes aktiviteter i området.',
#   46: 'Det blev fra første færd fra dansk side tilkendegivet,  at vi ville være indstillet på at overveje forskellige  genopbygningsindsatser.',
#   47: 'Vurdering af behov for støtte blev  foretaget sideløbende med indgåelse af  tilbagetagelsesaftalerne.',
#   48: 'På den måde var der en sammenhæng  mellem støtte og tilbagetagelsesaftaler.',
#   49: 'Noget andet er, at der ikke var en juridisk sammenhæng  mellem de to ting.',
#   50: 'At det forholder sig sådan, er først  bekræftet af myndighederne i Somaliland i en fælles  forståelse, der blev undertegnet efter indgåelse af  tilbagetagelsesaftalen, og siden i praksis dokumenteret, da  hjemsendelse af den første afviste somaliske asylansøger blev  gennemført for nogle få uger siden.',
#   51: 'Denne udsendelse fandt  sted, selv om det på det tidspunkt var klart efter afgørelsen  i Finansudvalget, at Danmark ikke ville yde  genopbygningshjælp til Somaliland.',
#   52: 'Beskyldningerne om menneskehandel og bestikkelse har  således vist sig at være grundløse.',
#   53: 'Regeringen finder fortsat, at vi skal arbejde videre på  at støtte genopbygningsindsatsen i Somalia.',
#   54: 'Dermed er det  også sagt, at regeringen ikke vil afvise, at det igen kan  blive aktuelt at anskue hjemsendelse og hjælp til  genopbygning i en sammenhæng.',
#   55: 'Det kan være i forhold til  Somalia eller i forhold til andre lande i en lignende  situation; for der kan opstå situationer, hvor der er en  sammenhæng, som der var her.',
#   56: 'International hjælp til genopbygning og normalisering af  situationen i krigshærgede og ødelagte lande gør det muligt  og realistisk for flygtninge fra området at vende tilbage,  også frivilligt, for selv at medvirke til genopbygning, og  samtidig medvirker velgennemførte genopbygningsprogrammer  til, at nye flygtningestrømme fra området undgås.',
#   57: 'Det er som  sagt en model, der støttes af internationale humanitære  organisationer.',
#   58: 'Når det er sagt, vil jeg endnu en gang understrege, at  denne regering ikke vil medvirke til aftaler, der kan have  karakter af menneskehandel, lige så lidt som regeringen vil  sætte menneskeliv på spil ved blot at dumpe afviste  asylansøgere i hjemlande, der ikke vil tage imod dem.'},
#  998: {0: 'Jeg synes, det er symptomatisk for det debatniveau, Dansk  Folkeparti bevæger sig på, når man her spørger, om det  fremover skal være sædvane at lave hjemsendelsesaftaler, der  indebærer udgifter over bistandsmidlerne.',
#   1: 'For det spørgsmål  kan jo besvares med et kort og klart nej.',
#   2: 'Mon ikke alle andre  end Dansk Folkeparti har forstået, at regeringen konsekvent  har holdt fast i, at midlerne til udviklingsbistand skal  anvendes i overensstemmelse med principperne i strategien for  dansk udviklingspolitik frem til år 2000?',
#   3: 'Som indenrigsministeren allerede har nævnt, var det  midler fra miljø- og katastroferammen, som regeringen i  sommer foreslog benyttet til projekter i Somalia i  forbindelse med hjemsendelse af afviste asylansøgere, og vi  håber stadig, at et flertal i Folketinget vil lytte til FN,  Dansk Flygtningehjælp og de mange andre, der har anbefalet  denne tanke.',
#   4: 'Afvisningen af aktstykket om de 44½ mio. kr. fra  MIKA-rammen var således beklagelig, både fordi Danmark derved  ikke levede op til, hvad der klart fremstod som en moralsk  forpligtelse, og fordi selve aktiviteterne som sådan burde  være realiseret.',
#   5: 'Minerydning, renovering af elforsyning og  veje og genopstart af undervisningen ville give  lokalsamfundene et løft, der kunne forbedre mulighederne for  de hjemvendte flygtninge.',
#   6: 'Hvis debatten i dag skal kunne tjene noget formål, må  det være at aflive nogle af de værste myter om flygtningene,  som bl.a. Dansk Folkeparti bliver ved med at udsprede.',
#   7: 'Jeg vil derfor gerne slå fast, at det er regeringens  politik, at flygtninge i videst muligt omfang skal hjælpes i  nærområderne, og det er også situationen i dag.',
#   8: 'Rent faktisk  ender 95 pct. af flygtningene fra krige og kriser i Afrika i  nabolandene.',
#   9: 'Jeg gentager: 95 pct. ender faktisk i  nabolandene.',
#   10: 'Når man ser på de vanskeligheder, som et rigt land som  Danmark har eller giver sig selv ved at håndtere en lille  brøkdel af alle disse nødstedte mennesker, er det ikke svært  at forestille sig, hvilken byrde det er for fattige lande som  f.eks. Etiopien eller Tanzania at tage imod de massive  flygtningestrømme.',
#   11: 'Derfor finansierer vi med ulandsmidler en  stor humanitær bistand for at hjælpe flygtningene i  nabolandene.',
#   12: "Danmark er faktisk en meget væsentlig donor på dette  område, særlig gennem FN's Flygtningehøjkommissariat, UNHCR.",
#   13: 'Alene i 1996 modtog UNHCR således 312 mio. kr. fra Danmark  til sit arbejde for verdens flygtninge, men også danske og  andre internationale organisationer, der hjælper flygtningene  i nærområderne, modtager støtte fra os.',
#   14: 'Mens flygtningene opholder sig i flygtningelejre i  nabolandene, omfatter støtten drift af lejrene samt  nødvendige mad- og medicinforsyninger for at sikre deres  eksistensgrundlag.',
#   15: 'Når forholdene i hjemlandet er  tilstrækkelig sikre, ydes der fra dansk side støtte til  frivillig tilbagevenden gennem transportstøtte og  nødhjælpspakker og anden starthjælp til de hjemvendte.',
#   16: 'Dette er faktisk i gang nu i Somalia-sammenhængen, hvor  UNHCR står for en repatriering fra flygtningelejre i Etiopien  i et omfang af 30.000-40.000 inden udgangen af dette år.',
#   17: 'Forholdene i flygtningenes hjemlande er imidlertid helt  afgørende for, om det lykkes at repatriere flygtningene.',
#   18: 'Ofte  er freden meget skrøbelig og kan let påvirkes af det, at  tusindvis af flygtninge kommer hjem til områder, hvor  boliger, hospitaler, skoler osv. er ødelagte.',
#   19: 'Kun ved at  forbedre forholdene i landet ved både at genopbygge ødelagte  faciliteter og at skabe et økonomisk livsgrundlag for  befolkningen kan nye flygtningestrømme eller en fortsættelse  af konflikten undgås.',
#   20: 'Ikke mindst gennem vores bidrag til de  forskellige multilaterale organisationer støtter Danmark  denne vigtige indsats.',
#   21: 'Vi har også været i front med fjernelsen af en af de  væsentligste hindringer for hjemvendte flygtninge med hensyn  til, om de tør komme hjem, nemlig landminer i de forskellige  hjemområder.',
#   22: 'Ikke alene har Danmark positivt medvirket til at  sikre et internationalt forbud mod landminer, men vi har også  stået i spidsen for bestræbelserne på at fjerne de miner, der  allerede er lagt ud.',
#   23: "Gennem betydelig støtte til FN's  aktiviteter til minerydning og til andre organisationers  indsats for støtte til mineofre har vi gjort en stor og  rigtig indsats fra dansk side, og jeg vil faktisk slutte med  at sige, at det, der piner mig mest ved afslaget på  MIKA-aktstykket, faktisk er, at vi nu ikke kommer i gang med  rydningen af landminer i Nordvestsomalia.",
#   24: '',
#   25: 'Forhandling'},
#  999: {0: 'Jeg vil gerne takke såvel indenrigsministeren som ministeren  for udviklingsbistand for svarene, selv om jeg selvsagt slet  ikke synes, at svarene i tilstrækkeligt omfang gav os en  fornemmelse af, at regeringen virkelig gør, hvad der står i  dens magt for at sørge for repatrieringsordninger, der er  tilstrækkelige.',
#   1: 'Ministrene brugte selvfølgelig en del tid på at redegøre  for forholdene omkring aftalen med Somaliland.',
#   2: 'Men hvis vi nu  vender os mod de personer, der eksempelvis skulle sendes  tilbage til Nordøstsomalia - var det ikke 10 personer efter  aftalen?',
#   3: '- så ville det jo være interessant at få oplyst, om  der er tegn i sol og måne på, at der hjemsendes 10 personer  som aftalt.',
#   4: 'Hvor mange er man oppe på nu?',
#   5: 'Jeg kan huske, at  det for ganske kort tid siden var en mediebegivenhed fra  regeringens side, at man fik hjemsendt én.',
#   6: 'Er der hjemsendt  fem nu, eller hvad er vi oppe på?',
#   7: 'Og hvornår har det fundet  sted?',
#   8: 'Kan vi få nogle svar på det?',
#   9: 'De aftaler, man har brugt masser af tid på ved  udsendelse af forskellige delegationer osv., og som i flere  omgange har resulteret i det, regeringen selv har betegnet  som gennembrud i pressen, er det noget, der egentlig har  battet noget?',
#   10: 'Er det noget, der har sikret hjemsendelse af  hvor mange personer, kære ministre?',
#   11: 'Jeg skal også bede om svar fra ministrene på, om den  hjemsendelse til Somalia, der så har fundet sted, har givet  anledning til overvejelser om inddragelse af  opholdstilladelse inden for den nuværende 3-års-frist i  udlændingelovens § 19.',
#   12: 'For hvis hjemsendelserne skal være en  succes, må det jo forventes, at regeringen får sat en bremse  på de forventede permanente opholdstilladelser i Danmark, når  det nu har vist sig, at der foruden afviste asylansøgere også  er en række flygtninge eller asylsøgere her i landet, som  efter vores opfattelse jo ikke på nogen måde er berettiget  til asyl og dermed til at opholde sig i landet.',
#   13: 'Hvad agter regeringen i det hele taget at gøre ved de  1.132 udlændinge, der ifølge den tidligere indenrigsministers  oplysninger venter på at blive udsendt af Danmark?',
#   14: 'Kan vi få  et klart svar på det?',
#   15: 'I sig selv virker det jo helt grotesk, at en udvist  person kan forhale sin egen hjemsendelse ved at nægte at  underskrive de nødvendige papirer.',
#   16: 'Vi har omkring 3.000  somaliere her i landet, som ikke har fået permanent  opholdstilladelse endnu.',
#   17: 'Den tilladelse bør efter Dansk  Folkepartis opfattelse heller ikke træde i kraft.',
#   18: 'Hvad er  regeringens holdning til det?',
#   19: 'Mener regeringen blot, at vi  skal lade 3-års-grænsen forløbe med det resultat, at  efterhånden som vi ikke får hjemsendelsesaftaler på plads, så  er der flere og flere asylsøgere, som opholder sig her i  landet, og som så får lov til at blive her?',
#   20: 'Så der er mange spørgsmål, som ikke er besvaret med det,  ministrene har sagt indtil nu.',
#   21: 'Det er vores opfattelse i  Dansk Folkeparti, at selvfølgelig er viljen til at hjælpe  folk i nød meget stor i den danske befolkning, specielt til  at hjælpe folk i deres egne nærområder, men også, når der er  krig tæt ved Danmark, til at hjælpe folk i Danmark.',
#   22: 'Men det er naturligvis en forudsætning for Danmark, at  det er en hjælp, der er tidsbegrænset, og at folk, når der  bliver fred i deres nærområder igen, så vender tilbage.',
#   23: 'I dag  sker det kun i meget begrænset omfang.',
#   24: 'Langt de fleste  udlændinge, som kommer til Danmark som asylsøgere,',
#   25: 'bliver i  Danmark.',
#   26: 'Det har vi set med eksjugoslaverne, og nu ser vi det  også med somalierne - en helt uholdbar situation efter Dansk  Folkepartis opfattelse.',
#   27: 'En af grundene er selvfølgelig den tåbelige 3-års-regel,  som betyder, at asylsøgere, som har opholdt sig i Danmark i  tre år og ét minut, får livsvarigt ophold i Danmark.',
#   28: 'Det så  vi for ganske få uger siden med de 2.000 kosovoalbanere, som  jo fik ophold i Danmark, fordi denne her periode var  overskredet.',
#   29: 'Vi har haft samråd om det.',
#   30: 'Der var ikke noget at  gøre.',
#   31: 'Natten mellem, jeg tror det var en fredag og lørdag,  blev tidsfristen overskredet.',
#   32: 'Så der er ikke noget at sige til, at det er svært at  lave hjemsendelsesaftaler.',
#   33: 'Jeg tror, den tidligere  indenrigsminister karakteriserede det på den måde, at der  direkte fra eksjugoslaviske føderale myndigheder blev  spekuleret i den her 3-års-grænse.',
#   34: 'Det synes jeg er vigtigt  at vi får debatteret.',
#   35: 'Der er efter vores opfattelse ikke noget inhumant eller  racistisk i at ønske ændringer i de her regler, men jeg må jo  spørge: Hvad særlig humant er der eksempelvis ved, at fordi  man har opholdt sig i Danmark i tre år, så får man  opholdstilladelse, selv om man ikke er berettiget til asyl?',
#   36: 'Så der er altså mange spørgsmål, og Dansk Folkepartis  opfattelse er den, at hvis man brugte lige så store  ressourcer på at sørge for hjemsendelse og lave  repatrieringsordninger, som man bruger på  integrationsdiskussion og på at integrere udlændinge i det  danske samfund, så ville man være nået langt længere, end man  er i dag.',
#   37: 'Vi så med betænkning nr. 1337 afgivet af det af  indenrigsministeren nedsatte integrationsudvalg, hvor mange  og store overvejelser der egentlig ligger omkring  integration.',
#   38: 'Det er fair nok, at der bliver lavet sådan nogle  ting, men det betyder også, at fokus i Danmark ligger på  integrering og ikke på repatrieringsordninger.',
#   39: 'Vi ønsker fra Dansk Folkepartis side, at vi i lidt  højere grad får fjernet fokus fra integreringsordninger og i  højere grad fokuserer på hjemsendelsesordninger, og vi håber,  at vi kan afslutte denne debat i dag med at blive enige om en  folketingsvedtagelse, som sørger for, at Folketinget og  regeringen fremover koncentrerer sig mere om  repatrieringsordninger end om integrering.',
#   40: 'Lad mig derfor afslutte med at fremsætte følgende:      Forslag til vedtagelse      »',
#   41: 'Folketinget opfordrer regeringen til at udarbejde en  omfattende hjemsendelsesplan, der kan udvirke, at asylsøgere,  som stammer fra områder, hvor der er fredelige forhold,  hjemsendes hurtigst muligt.',
#   42: '«  (Forslag til vedtagelse nr. V 9).'},
#  ...}

# %%
generator = Generator(model, BlameAnalysis)

# %%
json_out = {}

# Iterate through outer keys (0 to 36000)
for outer_key, inner_dict in tqdm.tqdm(paragraph_entry.items(), desc="LLama blame (GPU)"):
    json_out[outer_key] = {}  # Initialize nested dict for this outer key
    
    # Iterate through inner keys (0, 1, 2, ...)
    for inner_key, sentence in inner_dict.items():
        if sentence.strip() == "":
            pass
        else:
            prompt = f"""Perform blame identification on the following sentence.
            Sentence: {sentence}

            Rules:
            - Start by determining whether blame is present at all in the sentence
            - Set blame=true ONLY if someone/something is being blamed for causing a negative outcome
            - The "text" field must be EXACTLY the sentence provided above - do not modify it

            Output your analysis in JSON format."""
            
            with torch.no_grad():
                result = generator(prompt, max_new_tokens=256, use_cache=False)
            
            result_out = BlameAnalysis.model_validate_json(result)
            
            # Store in nested structure matching input
            json_out[outer_key][inner_key] = result_out.model_dump()
            
            with open("result_blame.json", "a") as f:
                json.dump({
                    "paragraph": outer_key,
                    "sentence": inner_key,
                    "result": result_out.model_dump()
                }, f, indent=2)
                f.write("\n")

# Save complete nested structure
with open("result_blame_complete.json", "w") as f:
    json.dump(json_out, f, indent=2)

torch.cuda.empty_cache()
# Out:
# LLama blame (GPU):   0%|          | 0/36314 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# LLama blame (GPU):   0%|          | 1/36314 [00:04<45:48:30,  4.54s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# LLama blame (GPU):   0%|          | 2/36314 [00:09<45:36:29,  4.52s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# LLama blame (GPU):   0%|          | 2/36314 [03:32<1069:26:59, 106.03s/it]
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[48], line 25
#      22 with torch.no_grad():
#      23     result = generator(prompt, max_new_tokens=256, use_cache=False)
# ---> 25 result_out = BlameAnalysis.model_validate_json(result)
#      27 # Store in nested structure matching input
#      28 json_out[outer_key][inner_key] = result_out.model_dump()
#
# File /work/RuneEgeskovTrust#9638/miniconda3/envs/blame/lib/python3.12/site-packages/pydantic/main.py:746, in BaseModel.model_validate_json(cls, json_data, strict, context, by_alias, by_name)
#     740 if by_alias is False and by_name is not True:
#     741     raise PydanticUserError(
#     742         'At least one of `by_alias` or `by_name` must be set to True.',
#     743         code='validate-by-alias-and-name-false',
#     744     )
# --> 746 return cls.__pydantic_validator__.validate_json(
#     747     json_data, strict=strict, context=context, by_alias=by_alias, by_name=by_name
#     748 )
#
# ValidationError: 1 validation error for BlameAnalysis
#   Invalid JSON: EOF while parsing a string at line 1 column 514 [type=json_invalid, input_value='{"text":"Erhvervsministe...00 - 20.00 - 21.00 - 22', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.11/v/json_invalid

# %%
paragraph_entry[2][676]
# Out:
# ''

# %%
from accelerate import Accelerator
import torch
import tqdm
import json
from itertools import islice

# 1. Initialize accelerator
accelerator = Accelerator()  # auto-detects GPUs, mixed precision, etc.
device = accelerator.device

# 2. Move your model to the accelerator
#generator = generator.to(device)  # or use pipeline(..., device_map='auto')
generator = accelerator.prepare(generator)

# 3. Helper for batching
def batch_iterable(iterable, batch_size):
    it = iter(iterable)
    while batch := list(islice(it, batch_size)):
        yield batch

# 4. Flatten input data
flat_sentences = []
for outer_key, inner_dict in paragraph_entry.items():
    for inner_key, sentence in inner_dict.items():
        flat_sentences.append((outer_key, inner_key, sentence))

# 5. Batched inference
BATCH_SIZE = 16
json_out = {}

for batch in tqdm.tqdm(batch_iterable(flat_sentences, BATCH_SIZE)):
    prompts = [
        f"""Perform blame identification on the following sentence.
        Sentence: {sentence}

        Rules:
        - Start by determining whether blame is present at all in the sentence
        - Set blame=true ONLY if someone/something is being blamed for causing a negative outcome
        - The "text" field must be EXACTLY the sentence provided above - do not modify it

        Output your analysis in JSON format. /no_think"""
        for (_, _, sentence) in batch
    ]

    with torch.no_grad():
        # accelerator handles distributing model and data automatically
        results = []
        for p in prompts:
            result = generator(p, max_new_tokens=512, use_cache=False)
            results.append(result)


    for (outer_key, inner_key, _), result in zip(batch, results):
        result_out = BlameAnalysis.model_validate_json(result)
        json_out.setdefault(outer_key, {})[inner_key] = result_out.model_dump()

        # incremental write
        with open("result_blame.json", "a") as f:
            json.dump({
                "paragraph": outer_key,
                "sentence": inner_key,
                "result": result_out.model_dump()
            }, f, indent=2)
            f.write("\n")

# save full results
with open("result_blame_complete.json", "w") as f:
    json.dump(json_out, f, indent=2)
# Out:
# 0it [00:00, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 0it [00:06, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 49
#      47     results = []
#      48     for p in prompts:
# ---> 49         result = generator(p, max_new_tokens=512, use_cache=False)
#      50         results.append(result)
#      53 for (outer_key, inner_key, _), result in zip(batch, results):
#
# File /work/RuneEgeskovTrust#9638/miniconda3/envs/blame/lib/python3.12/site-packages/outlines/generator.py:297, in SteerableGenerator.__call__(self, prompt, **inference_kwargs)
#     295 if self.logits_processor is not None:
#     296     self.logits_processor.reset()
# --> 297 return self.model.generate(
#     298     prompt, self.logits_processor, **inference_kwargs
#     299 )
#
# File /work/RuneEgeskovTrust#9638/miniconda3/envs/blame/lib/python3.12/site-packages/outlines/models/transformers.py:326, in Transformers.generate(self, model_input, output_type, **inference_kwargs)
#     323 prompts, inputs = self._prepare_model_inputs(model_input, False)
#     324 logits_processor = self.type_adapter.format_output_type(output_type)
# --> 326 generated_ids = self._generate_output_seq(
#     327     prompts,
#     328     inputs,
#     329     logits_processor=logits_processor,
#     330     **inference_kwargs,
#     331 )
#     333 # required for multi-modal models that return a 2D tensor even when
#     334 # num_return_sequences is 1
#     335 num_samples = inference_kwargs.get("num_return_sequences", 1)
#
# File /work/RuneEgeskovTrust#9638/miniconda3/envs/blame/lib/python3.12/site-packages/outlines/models/transformers.py:375, in Transformers._generate_output_seq(self, prompts, inputs, **inference_kwargs)
#     372 def _generate_output_seq(self, prompts, inputs, **inference_kwargs):
#     373     input_ids = inputs["input_ids"]
# --> 375     output_ids = self.model.generate(
#     376         **inputs,
#     377         **inference_kwargs,
#     378     )
#     380     # encoder-decoder returns output_ids only, decoder-only returns full seq ids
#     381     if self.model.config.is_encoder_decoder:
#
# File /work/RuneEgeskovTrust#9638/miniconda3/envs/blame/lib/python3.12/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File /work/RuneEgeskovTrust#9638/miniconda3/envs/blame/lib/python3.12/site-packages/transformers/generation/utils.py:2539, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2528     return GenerationMixin.generate(
#    2529         self,
#    2530         inputs,
#    (...)   2534         **kwargs,
#    2535     )
#    2537 elif generation_mode in (GenerationMode.SAMPLE, GenerationMode.GREEDY_SEARCH):
#    2538     # 11. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2539     result = self._sample(
#    2540         input_ids,
#    2541         logits_processor=prepared_logits_processor,
#    2542         stopping_criteria=prepared_stopping_criteria,
#    2543         generation_config=generation_config,
#    2544         synced_gpus=synced_gpus,
#    2545         streamer=streamer,
#    2546         **model_kwargs,
#    2547     )
#    2549 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2550     # 11. run beam sample
#    2551     result = self._beam_search(
#    2552         input_ids,
#    2553         logits_processor=prepared_logits_processor,
#    (...)   2557         **model_kwargs,
#    2558     )
#
# File /work/RuneEgeskovTrust#9638/miniconda3/envs/blame/lib/python3.12/site-packages/transformers/generation/utils.py:2870, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    2868     is_prefill = False
#    2869 else:
# -> 2870     outputs = model_forward(**model_inputs, return_dict=True)
#    2872 # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#    2873 model_kwargs = self._update_model_kwargs_for_generation(
#    2874     outputs,
#    2875     model_kwargs,
#    2876     is_encoder_decoder=self.config.is_encoder_decoder,
#    2877 )
#
# File /work/RuneEgeskovTrust#9638/miniconda3/envs/blame/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /work/RuneEgeskovTrust#9638/miniconda3/envs/blame/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /work/RuneEgeskovTrust#9638/miniconda3/envs/blame/lib/python3.12/site-packages/transformers/utils/generic.py:940, in can_return_tuple.<locals>.wrapper(self, *args, **kwargs)
#     938 if return_dict_passed is not None:
#     939     return_dict = return_dict_passed
# --> 940 output = func(self, *args, **kwargs)
#     941 if not return_dict and not isinstance(output, tuple):
#     942     output = output.to_tuple()
#
# File /work/RuneEgeskovTrust#9638/miniconda3/envs/blame/lib/python3.12/site-packages/transformers/models/llama/modeling_llama.py:459, in LlamaForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, cache_position, logits_to_keep, **kwargs)
#     427 @can_return_tuple
#     428 @auto_docstring
#     429 def forward(
#    (...)    440     **kwargs: Unpack[TransformersKwargs],
#     441 ) -> CausalLMOutputWithPast:
#     442     r"""
#     443     Example:
#     444
#    (...)    457     "Hey, are you conscious? Can you talk to me?\nI'm not conscious, but I can talk to you."
#     458     ```"""
# --> 459     outputs: BaseModelOutputWithPast = self.model(
#     460         input_ids=input_ids,
#     461         attention_mask=attention_mask,
#     462         position_ids=position_ids,
#     463         past_key_values=past_key_values,
#     464         inputs_embeds=inputs_embeds,
#     465         use_cache=use_cache,
#     466         cache_position=cache_position,
#     467         **kwargs,
#     468     )
#     470     hidden_states = outputs.last_hidden_state
#     471     # Only compute necessary logits, and do not upcast them to float if we are not computing the loss
#
# File /work/RuneEgeskovTrust#9638/miniconda3/envs/blame/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /work/RuneEgeskovTrust#9638/miniconda3/envs/blame/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /work/RuneEgeskovTrust#9638/miniconda3/envs/blame/lib/python3.12/site-packages/transformers/utils/generic.py:1064, in check_model_inputs.<locals>.wrapper(self, *args, **kwargs)
#    1061                 module.forward = make_capture_wrapper(module, original_forward, key, specs.index)
#    1062                 monkey_patched_layers.append((module, original_forward))
# -> 1064 outputs = func(self, *args, **kwargs)
#    1065 # Restore original forward methods
#    1066 for module, original_forward in monkey_patched_layers:
#
# File /work/RuneEgeskovTrust#9638/miniconda3/envs/blame/lib/python3.12/site-packages/transformers/models/llama/modeling_llama.py:395, in LlamaModel.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, cache_position, use_cache, **kwargs)
#     392 position_embeddings = self.rotary_emb(hidden_states, position_ids)
#     394 for decoder_layer in self.layers[: self.config.num_hidden_layers]:
# --> 395     hidden_states = decoder_layer(
#     396         hidden_states,
#     397         attention_mask=causal_mask,
#     398         position_ids=position_ids,
#     399         past_key_values=past_key_values,
#     400         cache_position=cache_position,
#     401         position_embeddings=position_embeddings,
#     402         **kwargs,
#     403     )
#     405 hidden_states = self.norm(hidden_states)
#     406 return BaseModelOutputWithPast(
#     407     last_hidden_state=hidden_states,
#     408     past_key_values=past_key_values,
#     409 )
#
# File /work/RuneEgeskovTrust#9638/miniconda3/envs/blame/lib/python3.12/site-packages/transformers/modeling_layers.py:94, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      91         logger.warning_once(message)
#      93     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 94 return super().__call__(*args, **kwargs)
#
# File /work/RuneEgeskovTrust#9638/miniconda3/envs/blame/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /work/RuneEgeskovTrust#9638/miniconda3/envs/blame/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /work/RuneEgeskovTrust#9638/miniconda3/envs/blame/lib/python3.12/site-packages/transformers/utils/deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File /work/RuneEgeskovTrust#9638/miniconda3/envs/blame/lib/python3.12/site-packages/transformers/models/llama/modeling_llama.py:308, in LlamaDecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_values, use_cache, cache_position, position_embeddings, **kwargs)
#     306 # Fully Connected
#     307 residual = hidden_states
# --> 308 hidden_states = self.post_attention_layernorm(hidden_states)
#     309 hidden_states = self.mlp(hidden_states)
#     310 hidden_states = residual + hidden_states
#
# File /work/RuneEgeskovTrust#9638/miniconda3/envs/blame/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /work/RuneEgeskovTrust#9638/miniconda3/envs/blame/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /work/RuneEgeskovTrust#9638/miniconda3/envs/blame/lib/python3.12/site-packages/transformers/models/llama/modeling_llama.py:67, in LlamaRMSNorm.forward(self, hidden_states)
#      65 variance = hidden_states.pow(2).mean(-1, keepdim=True)
#      66 hidden_states = hidden_states * torch.rsqrt(variance + self.variance_epsilon)
# ---> 67 return self.weight * hidden_states.to(input_dtype)
#
# File /work/RuneEgeskovTrust#9638/miniconda3/envs/blame/lib/python3.12/site-packages/torch/nn/modules/module.py:1949, in Module.__getattr__(self, name)
#    1944         self._backward_pre_hooks = OrderedDict()
#    1946 # It is crucial that the return type is not annotated as `Any`, otherwise type checking
#    1947 # on `torch.nn.Module` and all its subclasses is largely disabled as a result. See:
#    1948 # https://github.com/pytorch/pytorch/pull/115074
# -> 1949 def __getattr__(self, name: str) -> Union[Tensor, "Module"]:
#    1950     if "_parameters" in self.__dict__:
#    1951         _parameters = self.__dict__["_parameters"]
#
# KeyboardInterrupt:

# %%
import torch
import tqdm
import json
import time
import threading
from queue import Queue
from itertools import islice
from accelerate import Accelerator

# ---------- CONFIG ----------
BATCH_SIZE = 8                      # Adjust based on GPU memory
SAVE_INTERVAL = 200                 # Write every 200 results
CHECKPOINT_INTERVAL_SEC = 300       # Also checkpoint full dict every 5 min
OUTPUT_FILE = "result_blame.json"
CHECKPOINT_FILE = "result_blame_complete.json"
# -----------------------------

# ---------- SETUP ----------
accelerator = Accelerator()
device = accelerator.device

#generator = generator.to(device)
generator = accelerator.prepare(generator)

# Flatten nested dict structure
flat_sentences = []
for outer_key, inner_dict in paragraph_entry.items():
    for inner_key, sentence in inner_dict.items():
        flat_sentences.append((outer_key, inner_key, sentence))

def batch_iterable(iterable, batch_size):
    it = iter(iterable)
    while batch := list(islice(it, batch_size)):
        yield batch

# ---------- ASYNC WRITER ----------
write_queue = Queue()

def writer_thread():
    """Background writer to handle async JSON appends."""
    with open(OUTPUT_FILE, "a") as f:
        while True:
            batch = write_queue.get()
            if batch is None:
                break
            for item in batch:
                json.dump(item, f)
                f.write("\n")
            f.flush()

writer = threading.Thread(target=writer_thread, daemon=True)
writer.start()

# ---------- MAIN LOOP ----------
json_out = {}
buffer = []
last_checkpoint_time = time.time()

for batch in tqdm.tqdm(
    batch_iterable(flat_sentences, BATCH_SIZE),
    total=len(flat_sentences) // BATCH_SIZE,
    desc="LLama blame (multi-GPU)"
):
    prompts = [
        f"""Perform blame identification on the following sentence.
        Sentence: {sentence}

        Rules:
        - Start by determining whether blame is present at all in the sentence
        - Set blame=true ONLY if someone/something is being blamed for causing a negative outcome
        - The "text" field must be EXACTLY the sentence provided above - do not modify it

        Output your analysis in JSON format. /no_think"""
        for (_, _, sentence) in batch
    ]

    # Outlines generator only supports single-string input → iterate
    results = []
    with torch.no_grad():
        for p in prompts:
            result = generator(p, max_new_tokens=256, use_cache=False)
            results.append(result)

    # Process and buffer results
    for (outer_key, inner_key, _), result in zip(batch, results):
        result_out = BlameAnalysis.model_validate_json(result)
        json_out.setdefault(outer_key, {})[inner_key] = result_out.model_dump()

        buffer.append({
            "paragraph": outer_key,
            "sentence": inner_key,
            "result": result_out.model_dump()
        })

        # Flush to async writer when buffer fills
        if len(buffer) >= SAVE_INTERVAL:
            write_queue.put(buffer.copy())
            buffer.clear()
            torch.cuda.empty_cache()

    # Periodic checkpoint of full dict
    if (time.time() - last_checkpoint_time) > CHECKPOINT_INTERVAL_SEC:
        with open(CHECKPOINT_FILE, "w") as f:
            json.dump(json_out, f, indent=2)
        last_checkpoint_time = time.time()

# ---------- FINAL FLUSH ----------
if buffer:
    write_queue.put(buffer.copy())

write_queue.put(None)  # tell writer to stop
writer.join()

# Final save of complete structure
with open(CHECKPOINT_FILE, "w") as f:
    json.dump(json_out, f, indent=2)

torch.cuda.empty_cache()
print("✅ Processing complete — results written to disk.")
# Out:
# LLama blame (multi-GPU):   0%|          | 0/49877 [00:00<?, ?it/s]
# LLama blame (multi-GPU):   0%|          | 5/49877 [00:53<148:09:07, 10.69s/it]
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[20], line 86
#      84 # Process and buffer results
#      85 for (outer_key, inner_key, _), result in zip(batch, results):
# ---> 86     result_out = BlameAnalysis.model_validate_json(result)
#      87     json_out.setdefault(outer_key, {})[inner_key] = result_out.model_dump()
#      89     buffer.append({
#      90         "paragraph": outer_key,
#      91         "sentence": inner_key,
#      92         "result": result_out.model_dump()
#      93     })
#
# File /work/RuneEgeskovTrust#9638/miniconda3/envs/blame/lib/python3.12/site-packages/pydantic/main.py:746, in BaseModel.model_validate_json(cls, json_data, strict, context, by_alias, by_name)
#     740 if by_alias is False and by_name is not True:
#     741     raise PydanticUserError(
#     742         'At least one of `by_alias` or `by_name` must be set to True.',
#     743         code='validate-by-alias-and-name-false',
#     744     )
# --> 746 return cls.__pydantic_validator__.validate_json(
#     747     json_data, strict=strict, context=context, by_alias=by_alias, by_name=by_name
#     748 )
#
# ValidationError: 1 validation error for BlameAnalysis
#   Invalid JSON: EOF while parsing a string at line 1 column 891 [type=json_invalid, input_value='{"text": "Rules: Rules: ...s: Rules: Rules: Rules:', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.11/v/json_invalid
