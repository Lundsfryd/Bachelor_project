# %%
git clone https://github.com/alexandrainst/danlp.git
cd danlp
# minimum installation
pip install .
# or install all the packages
pip install .[all]
# Out:
# Downloading file /tmp/tmpkezhvj95
# 100% |########################################################################|

# %%
import danlp

# %%
from danlp.models import load_xlmr_coref_model

# load the coreference model
coref_model = load_xlmr_coref_model()

# a document is a list of tokenized sentences
doc = [["Lotte", "arbejder", "med", "Mads", "."], ["Hun", "er", "tandlæge", "."]]

# apply coreference resolution to the document and get a list of features (see below)
preds = coref_model.predict(doc)

# apply coreference resolution to the document and get a list of clusters
clusters = coref_model.predict_clusters(doc)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from danlp.models import load_xlmr_coref_model
#       3 # load the coreference model
#       4 coref_model = load_xlmr_coref_model()
#
# File /work/MarkusLundsfrydJensen#1865/miniconda3/envs/coref_updated/lib/python3.13/site-packages/danlp/models/__init__.py:2
#       1 from .spacy_models import *
# ----> 2 from .embeddings import *
#       3 from .flair_models import *
#       4 from .bert_models import *
#
# File /work/MarkusLundsfrydJensen#1865/miniconda3/envs/coref_updated/lib/python3.13/site-packages/danlp/models/embeddings.py:28
#      25 from tempfile import TemporaryDirectory
#      26 from time import sleep
# ---> 28 from gensim.models.keyedvectors import KeyedVectors
#      30 from danlp.download import MODELS, download_model, DEFAULT_CACHE_DIR, \
#      31     _unzip_process_func
#      33 AVAILABLE_EMBEDDINGS = ['wiki.da.wv', 'cc.da.wv', 'conll17.da.wv',
#      34                         'news.da.wv', 'sketchengine.da.wv', 'dslreddit.da.wv']
#
# ModuleNotFoundError: No module named 'gensim'
